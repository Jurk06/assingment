# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('C:\\Users\\rabis\\Desktop\\assingment\\asssin.xlsx')

# %%
df.head(10)
# Out:
#           m/z  Retention time (min) Accepted Compound ID  \
# 0  622.443865              6.435400         001_C24:0 PC
# 1  468.308355              4.331133         001_C24:0 PD
# 2  494.323962              4.469333    003_C16:1 LPC IST
# 3  496.339484              4.803700        004_C16:0 LPC
# 4  520.339703              4.643200    005_C18:2_IST_LPC
# 5  522.355344              4.977567        006_C18:1 LPC
# 6  524.370949              5.356517        007_C18:0 LPC
# 7  542.321560              4.540667        008_C20:5 LPC
# 8  544.339891              4.669950        009_C20:4 LPC
# 9  518.321398              4.803700        010_C20:3 LPC
#
#    2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 0               3.391827e+06               3.350603e+06
# 1               9.943031e+05               5.452427e+05
# 2               2.983384e+06               1.608636e+06
# 3               8.898708e+07               3.733250e+07
# ...

# %%
df['Accepted Compound ID'].isnull().value_counts()
# Out:
# False    93
# True     79
# Name: Accepted Compound ID, dtype: int64

# %%
x=df['Accepted Compound ID']

# %%
x.head()
# Out:
# 0         001_C24:0 PC
# 1         001_C24:0 PD
# 2    003_C16:1 LPC IST
# 3        004_C16:0 LPC
# 4    005_C18:2_IST_LPC
# Name: Accepted Compound ID, dtype: object

# %%
import re

# %% [markdown]
# y.split()

# %%
y.split()
# Out:
# ['001_C24:0', 'PC']

# %%
y='001_C24:0 PC'

# %%
x.isnull().value_counts(0)
# Out:
# False    93
# True     79
# Name: Accepted Compound ID, dtype: int64

# %%
x.dropna(inplace=True)

# %%
x.head()
# Out:
# 0         001_C24:0 PC
# 1         001_C24:0 PD
# 2    003_C16:1 LPC IST
# 3        004_C16:0 LPC
# 4    005_C18:2_IST_LPC
# Name: Accepted Compound ID, dtype: object

# %%
x.shape
# Out:
# (93,)

# %%
x.head()
# Out:
# 0         001_C24:0 PC
# 1         001_C24:0 PD
# 2    003_C16:1 LPC IST
# 3        004_C16:0 LPC
# 4    005_C18:2_IST_LPC
# Name: Accepted Compound ID, dtype: object

# %%
x
# Out:
# 0           001_C24:0 PC
# 1           001_C24:0 PD
# 2      003_C16:1 LPC IST
# 3          004_C16:0 LPC
# 4      005_C18:2_IST_LPC
# 5          006_C18:1 LPC
# 6          007_C18:0 LPC
# 7          008_C20:5 LPC
# 8          009_C20:4 LPC
# 9          010_C20:3 LPC
# 10         011_C22:6 LPC
# 11         013_C16:0 LPE
# 12         014_C18:2 LPE
# 13         015_C18:1 LPE
# 14         016_C18:0 LPE
# 15         017_C20:4 LPE
# 16         018_C22:6 LPE
# 17          019_C30:1 PC
# 18          020_C30:0 PC
# 19          021_C32:2 PC
# 20          022_C32:1 PC
# 21          023_C32:0 PC
# 22          025_C34:3 PC
# 23          026_C34:2 PC
# 24          027_C34:1 PC
# 25          028_C34:0 PC
# 26        029_C36:4 PC-A
# 27          032_C36:2 PC
# 28          033_C36:1 PC
# 29          035_C38:6 PC
#              ...
# 100                  cde
# 101                  def
# 102                  efg
# 103                  fgh
# 104                  ghi
# 105                  hij
# ...

# %%
x.iloc[3:9]
# Out:
# 3        004_C16:0 LPC
# 4    005_C18:2_IST_LPC
# 5        006_C18:1 LPC
# 6        007_C18:0 LPC
# 7        008_C20:5 LPC
# 8        009_C20:4 LPC
# Name: Accepted Compound ID, dtype: object

# %%
x.iloc[17:36]
# Out:
# 17      019_C30:1 PC
# 18      020_C30:0 PC
# 19      021_C32:2 PC
# 20      022_C32:1 PC
# 21      023_C32:0 PC
# 22      025_C34:3 PC
# 23      026_C34:2 PC
# 24      027_C34:1 PC
# 25      028_C34:0 PC
# 26    029_C36:4 PC-A
# 27      032_C36:2 PC
# 28      033_C36:1 PC
# 29      035_C38:6 PC
# 30      036_C38:4 PC
# 31      037_C38:3 PC
# 32      038_C38:2 PC
# 33     039_C40:10 PC
# 34      040_C40:9 PC
# 35      041_C40:6 PC
# Name: Accepted Compound ID, dtype: object

# %%
x.iloc[36:49]
# Out:
# 36      044_C34:3 PC plasmalogen
# 37      045_C34:2 PC plasmalogen
# 38    046_C34:1 PC plasmalogen-A
# 39    047_C34:1 PC plasmalogen-B
# 40    048_C36:5 PC plasmalogen-A
# 41    049_C36:5 PC plasmalogen-B
# 42      050_C36:4 PC plasmalogen
# 43      051_C36:3 PC plasmalogen
# 44      052_C36:2 PC plasmalogen
# 45      053_C36:1 PC plasmalogen
# 46      054_C38:7 PC plasmalogen
# 47      055_C38:6 PC plasmalogen
# 48      056_C38:4 PC plasmalogen
# Name: Accepted Compound ID, dtype: object

# %%
x.iloc[50:]
# Out:
# 87       no
# 88       op
# 89       pq
# 90       qr
# 91       st
# 92       tu
# 93       uv
# 94       vw
# 95       wx
# 96       xy
# 97       yz
# 98      abc
# 99      bcd
# 100     cde
# 101     def
# 102     efg
# 103     fgh
# 104     ghi
# 105     hij
# 106     ijk
# 107     jkl
# 108     klm
# 109     lmn
# 110     mno
# 111     nop
# 112     opq
# 113     pqr
# 114     qrs
# 115     rst
# 116     stu
# 117     tuv
# 118     uvw
# 119     vwx
# 120     wxy
# 121     xyz
# 122    abcd
# 123    bcde
# 124    cdef
# 125    defg
# 126    efgh
# 127    fghi
# 128    ghij
# 129    hijk
# Name: Accepted Compound ID, dtype: object

# %%
df.describe()
# Out:
#               m/z  Retention time (min)  2788e_WHI_BAA_LIP_PrefB01  \
# count  171.000000            172.000000               1.720000e+02
# mean   721.171962              9.148461               1.021759e+07
# std    222.581757              3.148762               3.179821e+07
# min   -968.766727            -12.873067               0.000000e+00
# 25%    665.609929              8.379192               1.989011e+05
# 50%    759.636860              9.134850               9.660191e+05
# 75%    819.623692             11.406317               6.123881e+06
# max    952.831543             13.229717               3.044127e+08
#
#        2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# count               1.720000e+02                1.720000e+02
# mean                1.599004e+07                1.691684e+07
# std                 4.504247e+07                4.555464e+07
# min                 9.828472e+03                0.000000e+00
# ...

# %%
df.head(20)
# Out:
#            m/z  Retention time (min) Accepted Compound ID  \
# 0   622.443865              6.435400         001_C24:0 PC
# 1   468.308355              4.331133         001_C24:0 PD
# 2   494.323962              4.469333    003_C16:1 LPC IST
# 3   496.339484              4.803700        004_C16:0 LPC
# 4   520.339703              4.643200    005_C18:2_IST_LPC
# 5   522.355344              4.977567        006_C18:1 LPC
# 6   524.370949              5.356517        007_C18:0 LPC
# 7   542.321560              4.540667        008_C20:5 LPC
# 8   544.339891              4.669950        009_C20:4 LPC
# 9   518.321398              4.803700        010_C20:3 LPC
# 10  568.339752              4.643200        011_C22:6 LPC
# 11  454.292716              4.821533        013_C16:0 LPE
# 12  478.292566              4.661033        014_C18:2 LPE
# 13  480.308339              4.990950        015_C18:1 LPE
# 14  482.324093              5.374350        016_C18:0 LPE
# ...

# %%
round(df['Retention time (min)'])
# Out:
# 0       6.0
# 1       4.0
# 2       4.0
# 3       5.0
# 4       5.0
# 5       5.0
# 6       5.0
# 7       5.0
# 8       5.0
# 9       5.0
# 10      5.0
# 11      5.0
# 12      5.0
# 13      5.0
# 14      5.0
# 15      5.0
# 16      5.0
# 17      8.0
# 18      8.0
# 19      8.0
# 20      8.0
# 21      9.0
# 22      8.0
# 23      8.0
# 24      9.0
# 25      9.0
# 26      8.0
# 27      9.0
# 28      9.0
# 29      8.0
#        ...
# 142    11.0
# 143    11.0
# 144    12.0
# 145    12.0
# 146    12.0
# 147    12.0
# 148    13.0
# 149    11.0
# 150    11.0
# 151    12.0
# 152    12.0
# 153    12.0
# 154    13.0
# 155    11.0
# 156    11.0
# 157    11.0
# 158    12.0
# 159    12.0
# 160    12.0
# 161    12.0
# 162    13.0
# 163   -13.0
# 164    13.0
# 165    11.0
# 166    11.0
# 167    12.0
# 168    12.0
# 169    12.0
# 170    12.0
# 171    11.0
# Name: Retention time (min), Length: 172, dtype: float64

# %%
z=round(df['Retention time (min)'])

# %%
z.head()
# Out:
# 0    6.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: Retention time (min), dtype: float64

# %%
df['Retention Time Roundoff (in mins)']=df['Retention Time Roundoff (in mins)']+round(df['Retention time (min)'])

# %%
del df['Retention Time Roundoff (in mins)']

# %%
df.head()
# Out:
#           m/z  Retention time (min) Accepted Compound ID  \
# 0  622.443865              6.435400         001_C24:0 PC
# 1  468.308355              4.331133         001_C24:0 PD
# 2  494.323962              4.469333    003_C16:1 LPC IST
# 3  496.339484              4.803700        004_C16:0 LPC
# 4  520.339703              4.643200    005_C18:2_IST_LPC
#
#    2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 0               3.391827e+06               3.350603e+06
# 1               9.943031e+05               5.452427e+05
# 2               2.983384e+06               1.608636e+06
# 3               8.898708e+07               3.733250e+07
# 4               1.687672e+07               1.148176e+07
#
#    2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# 0                3.321951e+06                3.434692e+06
# 1                6.704707e+05                5.744235e+05
# 2                1.820152e+06                1.857638e+06
# ...

# %%
df.insert(loc=2, column='Retention Time Roundoff (in mins)', value=z)

# %%
df.head()
# Out:
#           m/z  Retention time (min)  Retention Time Roundoff (in mins)  \
# 0  622.443865              6.435400                                6.0
# 1  468.308355              4.331133                                4.0
# 2  494.323962              4.469333                                4.0
# 3  496.339484              4.803700                                5.0
# 4  520.339703              4.643200                                5.0
#
#   Accepted Compound ID  2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 0         001_C24:0 PC               3.391827e+06               3.350603e+06
# 1         001_C24:0 PD               9.943031e+05               5.452427e+05
# 2    003_C16:1 LPC IST               2.983384e+06               1.608636e+06
# 3        004_C16:0 LPC               8.898708e+07               3.733250e+07
# 4    005_C18:2_IST_LPC               1.687672e+07               1.148176e+07
#
#    2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# ...

# %%
df['Retention Time Roundoff (in mins)'].value_counts()
# Out:
#  9.0     51
#  12.0    33
#  11.0    25
#  8.0     25
#  5.0     15
#  10.0     9
#  13.0     5
#  7.0      3
#  4.0      2
#  6.0      2
# -13.0     1
# -11.0     1
# Name: Retention Time Roundoff (in mins), dtype: int64

# %%
a=df[df['Retention Time Roundoff (in mins)']==9]

# %%
a.head()
# Out:
#            m/z  Retention time (min)  Retention Time Roundoff (in mins)  \
# 21  734.568583              8.544133                                9.0
# 24  760.584406              8.695717                                9.0
# 25  762.599777              9.003333                                9.0
# 27  786.600023              8.851750                                9.0
# 28  788.615843              9.137083                                9.0
#
#    Accepted Compound ID  2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 21         023_C32:0 PC               1.191209e+07               1.460640e+07
# 24         027_C34:1 PC               1.948096e+08               2.281313e+08
# 25         028_C34:0 PC               2.330523e+06               3.325653e+06
# 27         032_C36:2 PC               1.527782e+08               2.478751e+08
# 28         033_C36:1 PC               2.921420e+07               4.656533e+07
#
#     2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# ...

# %%
a1=a[4:].mean()

# %%
a.insert(loc=1050, column='mean', value=a1)

# %%
a.head()
# Out:
#            m/z  Retention time (min)  Retention Time Roundoff (in mins)  \
# 21  734.568583              8.544133                                9.0
# 24  760.584406              8.695717                                9.0
# 25  762.599777              9.003333                                9.0
# 27  786.600023              8.851750                                9.0
# 28  788.615843              9.137083                                9.0
#
#    Accepted Compound ID  2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 21         023_C32:0 PC               1.191209e+07               1.460640e+07
# 24         027_C34:1 PC               1.948096e+08               2.281313e+08
# 25         028_C34:0 PC               2.330523e+06               3.325653e+06
# 27         032_C36:2 PC               1.527782e+08               2.478751e+08
# 28         033_C36:1 PC               2.921420e+07               4.656533e+07
#
#     2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# ...

# %%
a['Mean']=a.mean(axis=1)
# Out:
# C:\Users\rabis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
del a['mean']

# %%
a.head()
# Out:
#            m/z  Retention time (min)  Retention Time Roundoff (in mins)  \
# 21  734.568583              8.544133                                9.0
# 24  760.584406              8.695717                                9.0
# 25  762.599777              9.003333                                9.0
# 27  786.600023              8.851750                                9.0
# 28  788.615843              9.137083                                9.0
#
#    Accepted Compound ID  2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 21         023_C32:0 PC               1.191209e+07               1.460640e+07
# 24         027_C34:1 PC               1.948096e+08               2.281313e+08
# 25         028_C34:0 PC               2.330523e+06               3.325653e+06
# 27         032_C36:2 PC               1.527782e+08               2.478751e+08
# 28         033_C36:1 PC               2.921420e+07               4.656533e+07
#
#     2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# ...

# %%
b=df[df['Retention Time Roundoff (in mins)']==12]

# %%
b['Mean']=b.mean(axis=1)
# Out:
# C:\Users\rabis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
b.head()
# Out:
#            m/z  Retention time (min)  Retention Time Roundoff (in mins)  \
# 91  614.586505             11.624767                               12.0
# 92  640.602099             11.718383                               12.0
# 93  642.617801             12.039383                               12.0
# 94  664.602059             11.548983                               12.0
# 95  666.617798             11.789717                               12.0
#
#    Accepted Compound ID  2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 91                   st               6.387420e+04               5.714274e+04
# 92                   tu               4.928309e+06               3.334989e+06
# 93                   uv               2.101646e+06               2.320464e+06
# 94                   vw               1.176070e+07               1.216498e+07
# 95                   wx               8.453848e+07               8.844820e+07
#
#     2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# ...

# %%
c=df[df['Retention Time Roundoff (in mins)']==11]

# %%
c['Mean']=c.mean(axis=1)
# Out:
# C:\Users\rabis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
c.head()
# Out:
#             m/z  Retention time (min)  Retention Time Roundoff (in mins)  \
# 98   688.602089             11.406317                               11.0
# 120  740.675704             10.911450                               11.0
# 121  764.675666             10.759867                               11.0
# 122  766.691241             11.013983                               11.0
# 123  768.706683             11.263650                               11.0
#
#     Accepted Compound ID  2788e_WHI_BAA_LIP_PrefB01  \
# 98                   abc               4.754397e+06
# 120                  wxy               1.630854e+04
# 121                  xyz               8.249569e+04
# 122                 abcd               1.535408e+05
# 123                 bcde               1.147787e+05
#
#      2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 98                1.009182e+07                1.274797e+07
# 120               1.170978e+05                4.424014e+04
# ...

# %%
d=df[df['Retention Time Roundoff (in mins)']==8]

# %%
d['Mean']=d.mean(axis=1)
# Out:
# C:\Users\rabis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
d.head()
# Out:
#            m/z  Retention time (min)  Retention Time Roundoff (in mins)  \
# 17  704.521970              7.723833                                8.0
# 18  706.537317              8.062650                                8.0
# 19  730.537396              7.884317                                8.0
# 20  732.553182              8.227600                                8.0
# 22  756.552766              8.080483                                8.0
#
#    Accepted Compound ID  2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 17         019_C30:1 PC               4.269350e+05               5.421553e+05
# 18         020_C30:0 PC               2.153106e+06               3.140539e+06
# 19         021_C32:2 PC               3.228137e+06               5.622733e+06
# 20         022_C32:1 PC               2.057741e+07               2.375065e+07
# 22         025_C34:3 PC               1.412701e+07               2.598133e+07
#
#     2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# ...

# %%
e=df[df['Retention Time Roundoff (in mins)']==5]

# %%
e['Mean']=e.mean(axis=1)
# Out:
# C:\Users\rabis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
e.head()
# Out:
#           m/z  Retention time (min)  Retention Time Roundoff (in mins)  \
# 3  496.339484              4.803700                                5.0
# 4  520.339703              4.643200                                5.0
# 5  522.355344              4.977567                                5.0
# 6  524.370949              5.356517                                5.0
# 7  542.321560              4.540667                                5.0
#
#   Accepted Compound ID  2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 3        004_C16:0 LPC               8.898708e+07               3.733250e+07
# 4    005_C18:2_IST_LPC               1.687672e+07               1.148176e+07
# 5        006_C18:1 LPC               2.028298e+07               1.129084e+07
# 6        007_C18:0 LPC               3.116341e+07               1.423354e+07
# 7        008_C20:5 LPC               7.124657e+05               5.169675e+05
#
#    2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# ...

# %%
f=df[df['Retention Time Roundoff (in mins)']==10]

# %%
f['Mean']=f.mean(axis=1)
# Out:
# C:\Users\rabis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
f.head()
# Out:
#            m/z  Retention time (min)  Retention Time Roundoff (in mins)  \
# 68  756.589163              9.569533                               10.0
# 77  622.612980              9.640867                               10.0
# 78  650.644178             10.059933                               10.0
# 79  648.628614              9.698817                               10.0
# 88  787.667472              9.511567                               10.0
#
#    Accepted Compound ID  2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 68                  NaN               7.954315e+03               1.753850e+04
# 77                  NaN               6.228317e+04               1.741183e+05
# 78                  NaN               3.265361e+05               5.466515e+05
# 79                  NaN               8.986217e+04               1.740355e+05
# 88                   op               1.290580e+07               2.404366e+07
#
#     2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# ...

# %%
g=df[df['Retention Time Roundoff (in mins)']==13]

# %%
g['Mean']=g.mean(axis=1)
# Out:
# C:\Users\rabis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
g.head()
# Out:
#             m/z  Retention time (min)  Retention Time Roundoff (in mins)  \
# 97   670.649308             12.565450                               13.0
# 148  880.831982             12.721483                               13.0
# 154  906.850069             12.788367                               13.0
# 162  930.847868             12.574367                               13.0
# 164  934.879479             13.229717                               13.0
#
#     Accepted Compound ID  2788e_WHI_BAA_LIP_PrefB01  \
# 97                    yz                457732.0321
# 148                  NaN                338986.7714
# 154                  NaN                473477.8437
# 162                  NaN                373510.1365
# 164                  NaN                     0.0000
#
#      2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 97                7.820099e+05                8.450819e+05
# 148               3.901262e+05                9.014345e+05
# ...
