# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Collecting the data¶

# %%
df=pd.read_excel('C:\\Users\\rabis\\Desktop\\assingment\\asssin.xlsx')

# %%
df.head(10)
# Out:
#           m/z  Retention time (min) Accepted Compound ID  \
# 0  622.443865              6.435400         001_C24:0 PC
# 1  468.308355              4.331133         001_C24:0 PD
# 2  494.323962              4.469333    003_C16:1 LPC IST
# 3  496.339484              4.803700        004_C16:0 LPC
# 4  520.339703              4.643200    005_C18:2_IST_LPC
# 5  522.355344              4.977567        006_C18:1 LPC
# 6  524.370949              5.356517        007_C18:0 LPC
# 7  542.321560              4.540667        008_C20:5 LPC
# 8  544.339891              4.669950        009_C20:4 LPC
# 9  518.321398              4.803700        010_C20:3 LPC
#
#    2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 0               3.391827e+06               3.350603e+06
# 1               9.943031e+05               5.452427e+05
# 2               2.983384e+06               1.608636e+06
# 3               8.898708e+07               3.733250e+07
# ...

# %% [markdown]
# # Sorting Null and Non-Null value¶

# %%
df['Accepted Compound ID'].isnull().value_counts()
# Out:
# False    93
# True     79
# Name: Accepted Compound ID, dtype: int64

# %% [markdown]
# # 79 Ids were misssing out of 172

# %% [markdown]
# # 1) In third column “Accepted Compound ID”, you need to filter out all the data for metabolite ids ending with: ‘PC’, ‘LPC’ and ‘plasmalogen’, and create 3 child datasets (1 for each compound id) from the data in input file

# %%
df1=df.iloc[3:9] #this is the one of the first task of spliting the dataframe into daughter ones.'LPC' ids only
df1.head()
# Out:
#           m/z  Retention time (min) Accepted Compound ID  \
# 3  496.339484              4.803700        004_C16:0 LPC
# 4  520.339703              4.643200    005_C18:2_IST_LPC
# 5  522.355344              4.977567        006_C18:1 LPC
# 6  524.370949              5.356517        007_C18:0 LPC
# 7  542.321560              4.540667        008_C20:5 LPC
#
#    2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 3               8.898708e+07               3.733250e+07
# 4               1.687672e+07               1.148176e+07
# 5               2.028298e+07               1.129084e+07
# 6               3.116341e+07               1.423354e+07
# 7               7.124657e+05               5.169675e+05
#
#    2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# 3                4.367946e+07                3.549519e+07
# 4                1.339046e+07                9.036667e+06
# 5                1.181568e+07                1.005478e+07
# ...

# %%
df2=df.iloc[17:36]  #this is the one of the first task of spliting the dataframe into daughter ones.'PC' ids only
df2.head()
# Out:
#            m/z  Retention time (min) Accepted Compound ID  \
# 17  704.521970              7.723833         019_C30:1 PC
# 18  706.537317              8.062650         020_C30:0 PC
# 19  730.537396              7.884317         021_C32:2 PC
# 20  732.553182              8.227600         022_C32:1 PC
# 21  734.568583              8.544133         023_C32:0 PC
#
#     2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 17               4.269350e+05               5.421553e+05
# 18               2.153106e+06               3.140539e+06
# 19               3.228137e+06               5.622733e+06
# 20               2.057741e+07               2.375065e+07
# 21               1.191209e+07               1.460640e+07
#
#     2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# 17                4.136959e+05                6.974573e+05
# 18                2.299525e+06                2.971443e+06
# 19                4.883108e+06                5.377037e+06
# ...

# %%
df3=df.iloc[36:50]   #this is the one of the first task of spliting the dataframe into daughter ones.'plasmalogen' ids only
df3.head()
# Out:
#            m/z  Retention time (min)        Accepted Compound ID  \
# 36  742.573952              8.691267    044_C34:3 PC plasmalogen
# 37  744.589128              8.700183    045_C34:2 PC plasmalogen
# 38  746.604953              8.989967  046_C34:1 PC plasmalogen-A
# 39  746.605103              9.293117  047_C34:1 PC plasmalogen-B
# 40  766.573112              8.441600  048_C36:5 PC plasmalogen-A
#
#     2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 36               8.114177e+06               5.823218e+06
# 37               5.164247e+06               4.174689e+06
# 38               5.097486e+06               4.935206e+06
# 39               6.675984e+04               5.397173e+04
# 40               4.379021e+05               6.725083e+05
#
#     2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# 36                3.405916e+06                3.500070e+06
# 37                2.431541e+06                2.338340e+06
# ...

# %%
df4=df.iloc[50:]  #Though I no need to filter this part as it was not a part of task still 
df4.head()
# Out:
#            m/z  Retention time (min) Accepted Compound ID  \
# 50  716.520812              8.388100                  NaN
# 51  740.522436              8.414850                  NaN
# 52  742.536600              8.544133                  NaN
# 53  744.553588              8.851750                  NaN
# 54  746.569574              9.141533                  NaN
#
#     2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 50               210636.43160               3.702604e+05
# 51               452143.64430               6.320614e+05
# 52               118690.40170               4.684538e+05
# 53               545889.78150               1.156453e+06
# 54                47854.75302               1.604900e+05
#
#     2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# 50                2.136214e+05                3.153565e+05
# 51                4.379633e+05                7.959380e+05
# 52                3.163748e+05                3.815938e+05
# ...

# %% [markdown]
# # 2) Add a new column in the parent dataset with the name “Retention Time Roundoff (in mins)”. This column should have rounded-off values of the corresponding retention time. Retention time should be rounded-off to the nearest natural number¶

# %%
z=round(df['Retention time (min)']) #First I have taken the round off value of the desired column 
z.head()
# Out:
# 0    6.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: Retention time (min), dtype: float64

# %%
df.insert(loc=2, column='Retention Time Roundoff(in mins)', value=z) # Addition of new cell to mother dataframe.

# %%
df.head()
# Out:
#           m/z  Retention time (min)  Retention Time Roundoff(in mins)  \
# 0  622.443865              6.435400                               6.0
# 1  468.308355              4.331133                               4.0
# 2  494.323962              4.469333                               4.0
# 3  496.339484              4.803700                               5.0
# 4  520.339703              4.643200                               5.0
#
#   Accepted Compound ID  2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 0         001_C24:0 PC               3.391827e+06               3.350603e+06
# 1         001_C24:0 PD               9.943031e+05               5.452427e+05
# 2    003_C16:1 LPC IST               2.983384e+06               1.608636e+06
# 3        004_C16:0 LPC               8.898708e+07               3.733250e+07
# 4    005_C18:2_IST_LPC               1.687672e+07               1.148176e+07
#
#    2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# ...

# %% [markdown]
# # 3)After this, you should find the mean of all the metabolites which have same "Retention Time Roundoff" across all the samples. The resultant of above operation should be a new data-frame where you have to include the "Retention Time Roundoff" column and all samples. You don't have to include columns like m/z, Accepted Compound Id and Retention time

# %%
df.drop(['m/z', 'Retention time (min)', 'Accepted Compound ID'], axis=1, inplace=True) #Excludeed the column that won't require
                                                                                       #As per the assingment

# %%
df.head()
# Out:
#    Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 0                               6.0               3.391827e+06
# 1                               4.0               9.943031e+05
# 2                               4.0               2.983384e+06
# 3                               5.0               8.898708e+07
# 4                               5.0               1.687672e+07
#
#    2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 0               3.350603e+06                3.321951e+06
# 1               5.452427e+05                6.704707e+05
# 2               1.608636e+06                1.820152e+06
# 3               3.733250e+07                4.367946e+07
# 4               1.148176e+07                1.339046e+07
#
#    2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 0                3.434692e+06                3.256514e+06
# 1                5.744235e+05                5.051156e+05
# 2                1.857638e+06                1.042530e+06
# ...

# %%
df['Retention Time Roundoff(in mins)'].value_counts()   #Sorted the column of having same value of Retention time Roundoff
# Out:
#  9.0     51
#  12.0    33
#  11.0    25
#  8.0     25
#  5.0     15
#  10.0     9
#  13.0     5
#  7.0      3
#  4.0      2
#  6.0      2
# -13.0     1
# -11.0     1
# Name: Retention Time Roundoff(in mins), dtype: int64

# %%
a=df[df['Retention Time Roundoff(in mins)']==9]               #Forming an new data frame contining round off value of 9 only
a['Mean']=a.mean(axis=1)
a.head()
# Out:
#     Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 21                               9.0               1.191209e+07
# 24                               9.0               1.948096e+08
# 25                               9.0               2.330523e+06
# 27                               9.0               1.527782e+08
# 28                               9.0               2.921420e+07
#
#     2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 21               1.460640e+07                1.001111e+07
# 24               2.281313e+08                1.944800e+08
# 25               3.325653e+06                2.877543e+06
# 27               2.478751e+08                2.482296e+08
# 28               4.656533e+07                5.123899e+07
#
#     2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 21                1.037297e+07                1.500000e+07
# 24                2.435788e+08                2.637545e+08
# ...

# %%
a1=df[df['Retention Time Roundoff(in mins)']==12]     #Forming an new data frame contining round off value of 12 only
a1['Mean']=a1.mean(axis=1)
a1.head()
# Out:
#     Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 91                              12.0               6.387420e+04
# 92                              12.0               4.928309e+06
# 93                              12.0               2.101646e+06
# 94                              12.0               1.176070e+07
# 95                              12.0               8.453848e+07
#
#     2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 91               5.714274e+04                3.017779e+04
# 92               3.334989e+06                3.351483e+06
# 93               2.320464e+06                1.832212e+06
# 94               1.216498e+07                1.265608e+07
# 95               8.844820e+07                7.856095e+07
#
#     2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 91                3.777756e+04                1.193695e+05
# 92                4.699635e+06                3.723302e+06
# ...

# %%
a2=df[df['Retention Time Roundoff(in mins)']==11]   #Forming an new data frame contining round off value of 11 only
a2['Mean']=a2.mean(axis=1)
a2.head()
# Out:
#      Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 98                               11.0               4.754397e+06
# 120                              11.0               1.630854e+04
# 121                              11.0               8.249569e+04
# 122                              11.0               1.535408e+05
# 123                              11.0               1.147787e+05
#
#      2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 98                1.009182e+07                1.274797e+07
# 120               1.170978e+05                4.424014e+04
# 121               2.764868e+05                1.706694e+05
# 122               6.493211e+05                3.937360e+05
# 123               6.590676e+05                4.229227e+05
#
#      2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 98                 8.601012e+06                6.920781e+06
# 120                4.453735e+04                2.536790e+05
# ...

# %%
a3=df[df['Retention Time Roundoff(in mins)']==8]  #Forming an new data frame contining round off value of 8 only
a3['Mean']=a3.mean(axis=1)
a3.head()
# Out:
#     Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 17                               8.0               4.269350e+05
# 18                               8.0               2.153106e+06
# 19                               8.0               3.228137e+06
# 20                               8.0               2.057741e+07
# 22                               8.0               1.412701e+07
#
#     2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 17               5.421553e+05                4.136959e+05
# 18               3.140539e+06                2.299525e+06
# 19               5.622733e+06                4.883108e+06
# 20               2.375065e+07                1.975383e+07
# 22               2.598133e+07                2.093269e+07
#
#     2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 17                6.974573e+05                5.284007e+05
# 18                2.971443e+06                3.286844e+06
# ...

# %%
a4=df[df['Retention Time Roundoff(in mins)']==5]  #Forming an new data frame contining round off value of 5 only
a4['Mean']=a4.mean(axis=1)
a4.head()
# Out:
#    Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 3                               5.0               8.898708e+07
# 4                               5.0               1.687672e+07
# 5                               5.0               2.028298e+07
# 6                               5.0               3.116341e+07
# 7                               5.0               7.124657e+05
#
#    2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 3               3.733250e+07                4.367946e+07
# 4               1.148176e+07                1.339046e+07
# 5               1.129084e+07                1.181568e+07
# 6               1.423354e+07                1.981950e+07
# 7               5.169675e+05                6.069609e+05
#
#    2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 3                3.549519e+07                2.786716e+07
# 4                9.036667e+06                9.049924e+06
# 5                1.005478e+07                6.771306e+06
# ...

# %%
a5=df[df['Retention Time Roundoff(in mins)']==10] #Forming an new data frame contining round off value of 10 only
a5['Mean']=a5.mean(axis=1)
a5.head()
# Out:
#     Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 68                              10.0               7.954315e+03
# 77                              10.0               6.228317e+04
# 78                              10.0               3.265361e+05
# 79                              10.0               8.986217e+04
# 88                              10.0               1.290580e+07
#
#     2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 68               1.753850e+04                1.544682e+03
# 77               1.741183e+05                2.283187e+05
# 78               5.466515e+05                5.990917e+05
# 79               1.740355e+05                1.910764e+05
# 88               2.404366e+07                2.561388e+07
#
#     2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 68                2.555075e+03                3.898286e+04
# 77                1.780077e+05                2.851699e+05
# ...

# %%
a6=df[df['Retention Time Roundoff(in mins)']==13]
a6['Mean']=a6.mean(axis=1)
a6.head()
# Out:
#      Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 97                               13.0                457732.0321
# 148                              13.0                338986.7714
# 154                              13.0                473477.8437
# 162                              13.0                373510.1365
# 164                              13.0                     0.0000
#
#      2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 97                7.820099e+05                8.450819e+05
# 148               3.901262e+05                9.014345e+05
# 154               8.119168e+05                2.022982e+06
# 162               1.414846e+06                2.094235e+06
# 164               9.828472e+03                3.711061e+04
#
#      2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 97                 6.152550e+05                1.087939e+06
# 148                8.599461e+05                1.134892e+06
# ...

# %%
a7=df[df['Retention Time Roundoff(in mins)']==7]
a7['Mean']=a7.mean(axis=1)
a7.head()
# Out:
#      Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 74                                7.0               7.988344e+05
# 75                                7.0               2.391905e+06
# 106                               7.0               2.359211e+04
#
#      2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 74                211054.87580                     0.00000
# 75                524027.88310                     0.00000
# 106                21399.74876                 21972.53218
#
#      2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 74                     0.000000                 1343.766312
# 75                  2673.531647                 1029.408936
# 106                22304.653770                21446.843060
#
#      2792_WHI_BAA_LIP_406434-39  2793_WHI_BAA_LIP_314098-48  \
# 74                  3006.099546                     0.00000
# 75                  1634.353210                     0.00000
# ...

# %%
a8=df[df['Retention Time Roundoff(in mins)']==4]
a8['Mean']=a8.mean(axis=1)
a8.head()
# Out:
#    Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 1                               4.0               9.943031e+05
# 2                               4.0               2.983384e+06
#
#    2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 1               5.452427e+05                6.704707e+05
# 2               1.608636e+06                1.820152e+06
#
#    2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 1                5.744235e+05                5.051156e+05
# 2                1.857638e+06                1.042530e+06
#
#    2792_WHI_BAA_LIP_406434-39  2793_WHI_BAA_LIP_314098-48  \
# 1                6.699923e+05                3.373603e+05
# 2                1.748126e+06                1.337870e+06
#
#    2794_WHI_BAA_LIP_408824-42  2795_WHI_BAA_LIP_258465-37      ...       \
# 1                5.704414e+05                5.490108e+05      ...
# 2                1.389622e+06                1.749063e+06      ...
#
# ...

# %%
a9=df[df['Retention Time Roundoff(in mins)']==6]
a9['Mean']=a9.mean(axis=1)
a9.head()
# Out:
#      Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 0                                 6.0               3.391827e+06
# 105                               6.0               3.085456e+04
#
#      2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 0                 3.350603e+06                3.321951e+06
# 105               4.059427e+04                1.932994e+04
#
#      2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 0                  3.434692e+06                3.256514e+06
# 105                2.273789e+04                2.033966e+04
#
#      2792_WHI_BAA_LIP_406434-39  2793_WHI_BAA_LIP_314098-48  \
# 0                  3.396340e+06                3.371074e+06
# 105                1.774422e+04                1.747923e+04
#
#      2794_WHI_BAA_LIP_408824-42  2795_WHI_BAA_LIP_258465-37      ...       \
# 0                  3.303754e+06                3.388552e+06      ...
# 105                1.791338e+04                1.851744e+04      ...
#
# ...

# %%
a10=df[df['Retention Time Roundoff(in mins)']==-13]
a10['Mean']=a10.mean(axis=1)
a10.head()
# Out:
#      Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 163                             -13.0                50619.47475
#
#      2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 163                285275.5164                 598809.6782
#
#      2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 163                 390079.9631                 1319167.907
#
#      2792_WHI_BAA_LIP_406434-39  2793_WHI_BAA_LIP_314098-48  \
# 163                 1057267.296                 165400.5044
#
#      2794_WHI_BAA_LIP_408824-42  2795_WHI_BAA_LIP_258465-37      ...        \
# 163                  444891.932                 291057.6371      ...
#
#      3734reinja_WHI_BAA_LIP_420751-38  3735_WHI_BAA_LIP_202764-45  \
# 163                        60120.5103                  15191.2104
#
#      3736_WHI_BAA_LIP_236674-35  3737_WHI_BAA_LIP_468528-53  \
# 163                    63189.53                 83850.61049
#
# ...

# %%
a11=df[df['Retention Time Roundoff(in mins)']==-11]
a11['Mean']=a11.mean(axis=1)
a10.head()
# Out:
#      Retention Time Roundoff(in mins)  2788e_WHI_BAA_LIP_PrefB01  \
# 163                             -13.0                50619.47475
#
#      2788f_WHI_BAA_LIP_PrefA01  2789_WHI_BAA_LIP_331530-51  \
# 163                285275.5164                 598809.6782
#
#      2790_WHI_BAA_LIP_422284-42  2791_WHI_BAA_LIP_330045-45  \
# 163                 390079.9631                 1319167.907
#
#      2792_WHI_BAA_LIP_406434-39  2793_WHI_BAA_LIP_314098-48  \
# 163                 1057267.296                 165400.5044
#
#      2794_WHI_BAA_LIP_408824-42  2795_WHI_BAA_LIP_258465-37      ...        \
# 163                  444891.932                 291057.6371      ...
#
#      3734reinja_WHI_BAA_LIP_420751-38  3735_WHI_BAA_LIP_202764-45  \
# 163                        60120.5103                  15191.2104
#
#      3736_WHI_BAA_LIP_236674-35  3737_WHI_BAA_LIP_468528-53  \
# 163                    63189.53                 83850.61049
#
# ...

# %% [markdown]
# # I have tried to solve the assignent and come up these results
